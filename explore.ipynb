# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", 50)

# %%
raw = pd.read_csv("data/raw_data.csv")
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
raw.nunique()
# Out:
# ID                     2240
# Year_Birth               59
# Education                 5
# Marital_Status            8
# Income                 1974
# Kidhome                   3
# Teenhome                  3
# Dt_Customer             663
# Recency                 100
# MntWines                776
# MntFruits               158
# MntMeatProducts         558
# MntFishProducts         182
# MntSweetProducts        177
# MntGoldProds            213
# NumDealsPurchases        15
# NumWebPurchases          15
# NumCatalogPurchases      14
# NumStorePurchases        14
# NumWebVisitsMonth        16
# AcceptedCmp3              2
# AcceptedCmp4              2
# AcceptedCmp5              2
# AcceptedCmp1              2
# AcceptedCmp2              2
# Complain                  2
# Z_CostContact             1
# Z_Revenue                 1
# Response                  2
# dtype: int64

# %%
raw.Z_CostContact.head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: Z_CostContact, dtype: int64

# %%
raw.Z_Revenue.head()
# Out:
# 0    11
# 1    11
# 2    11
# 3    11
# 4    11
# Name: Z_Revenue, dtype: int64

# %%
# Dropping `Z_CostContact` and `Z_Revenue` because it only has 1 unique value. `ID` is dropped as well.
data = raw.drop(columns= ["Z_CostContact", "Z_Revenue", "ID"])

# %%
data.columns = data.columns.str.lower()
data.sample(2)
# Out:
#       year_birth   education marital_status   income  kidhome  teenhome  \
# 869         1979  Graduation       Together  30545.0        1         0
# 1282        1957         PhD        Married  37633.0        1         1
#
#      dt_customer  recency  mntwines  mntfruits  mntmeatproducts  \
# 869   17-10-2012       71         4         12               15
# 1282  20-09-2012       49        13          4               20
#
#       mntfishproducts  mntsweetproducts  mntgoldprods  numdealspurchases  \
# 869                19                 7            12                  2
# 1282                0                 0             1                  2
#
#       numwebpurchases  numcatalogpurchases  numstorepurchases  \
# 869                 2                    0                  3
# 1282                1                    0                  3
#
#       numwebvisitsmonth  acceptedcmp3  acceptedcmp4  acceptedcmp5  \
# 869                   7             0             0             0
# ...

# %%
# Understanding customer age
age = pd.Timestamp.today().year - data["year_birth"]
data.insert(0,"age",age)
plt.hist(data["age"], bins=20)
plt.show()

# %%
# It appears that there are people older than 90
data.query("age > 90")
# Out:
#      age  year_birth education marital_status   income  kidhome  teenhome  \
# 192  125        1900  2n Cycle       Divorced  36640.0        1         0
# 239  132        1893  2n Cycle         Single  60182.0        0         1
# 339  126        1899       PhD       Together  83532.0        0         0
#
#     dt_customer  recency  mntwines  mntfruits  mntmeatproducts  \
# 192  26-09-2013       99        15          6                8
# 239  17-05-2014       23         8          0                5
# 339  26-09-2013       36       755        144              562
#
#      mntfishproducts  mntsweetproducts  mntgoldprods  numdealspurchases  \
# 192                7                 4            25                  1
# 239                7                 0             2                  1
# 339              104                64           224                  1
#
#      numwebpurchases  numcatalogpurchases  numstorepurchases  \
# ...

# %%
# These observations will be dropped as well as it is likely that these data points are untrustworthy
data = data[data["age"] < 90]

# The year_birth column will also be dropped

# %%
# Box plot now shows a more credible customer age range
plt.boxplot(data["age"])
plt.show()

# %%
# Investigating Income which has missing data
data[data["income"].isna()]
# Out:
#       age  year_birth   education marital_status  income  kidhome  teenhome  \
# 10     42        1983  Graduation        Married     NaN        1         0
# 27     39        1986  Graduation         Single     NaN        1         0
# 43     66        1959         PhD         Single     NaN        0         0
# 48     74        1951  Graduation         Single     NaN        2         1
# 58     43        1982  Graduation         Single     NaN        1         0
# 71     52        1973    2n Cycle        Married     NaN        1         0
# 90     68        1957         PhD        Married     NaN        2         1
# 91     68        1957  Graduation         Single     NaN        1         1
# 92     52        1973      Master       Together     NaN        0         0
# 128    64        1961         PhD        Married     NaN        0         1
# 133    62        1963  Graduation        Married     NaN        0         1
# ...

# %%
data.income
# Out:
# 0       58138.0
# 1       46344.0
# 2       71613.0
# 3       26646.0
# 4       58293.0
#          ...
# 2235    61223.0
# 2236    64014.0
# 2237    56981.0
# 2238    69245.0
# 2239    52869.0
# Name: income, Length: 2237, dtype: float64

# %%
# Imputing missing income with the median based on education
data.groupby("education")["income"].transform(lambda x: x.fillna(x.median()))
# Out:
# 0       58138.0
# 1       46344.0
# 2       71613.0
# 3       26646.0
# 4       58293.0
#          ...
# 2235    61223.0
# 2236    64014.0
# 2237    56981.0
# 2238    69245.0
# 2239    52869.0
# Name: income, Length: 2237, dtype: float64
